# %% [markdown]
# # git repo crawl
#
# 该范例里，我们将针对所有包含关键词“property”，为“verilog”语言的repo进行爬取，结果将以 `<repo_name>.zip` 的形式保存在`data\repos`文件夹下。
#
# steps:
#
# 1. get all repos written in language 'systemverilog';
# 2. filter these repos with rule: keyword 'property' must appear in code;
# 3. download all repos;
#
#
# # github API tutorial
#
# * [官方文档](https://docs.github.com/en/rest?apiVersion=2022-11-28)
#
# - - [search API](https://docs.github.com/en/rest/search/search?apiVersion=2022-11-28)
#
# - - [设置personal token](https://github.com/settings/tokens)
#
# * [入门blog](https://blog.csdn.net/weixin_39132520/article/details/114925354)
#
#
# # 注意事项：
#
# * github's search API limit is set to return at most 1000 items, therefore we need to split whole query into chunks to retrieve items ranked over 1000
#
# * For authenticated requests, 30 requests per minute, For unauthenticated requests, the rate limit allows you to make up to 10 requests per minute. 在code search里，实验来看，只能最快每分钟search 10次，所以我们应该还是属于 unauthenticated，虽然是给了token的（不给token，code search都用不了）。
#
# * 对小数据量的repo爬取，同步执行就ok了。如要涉及到更大数据量的爬取，需要分布式，可以参考[这篇博客](https://ask.hellobi.com/blog/lrysjtu/3859)

# %%
import time
import json
import requests

import os
from os import path as osp

import subprocess
import wget

# %%
from dotenv import load_dotenv
import  os
_TOKEN = os.getenv('git_token')

HEADERS = {'Authorization': f'Bearer {_TOKEN}'}
ROOT = '.'

def test_api():
    url = 'https://api.github.com/octocat'

    resp = requests.get(url, headers=HEADERS)
    print(resp.content.decode('utf8'))

test_api()
# Out:
#                MMM.           .MMM
#                MMMMMMMMMMMMMMMMMMM
#                MMMMMMMMMMMMMMMMMMM      ____________________________
#               MMMMMMMMMMMMMMMMMMMMM    |                            |
#              MMMMMMMMMMMMMMMMMMMMMMM   | Practicality beats purity. |
#             MMMMMMMMMMMMMMMMMMMMMMMM   |_   ________________________|
#             MMMM::- -:::::::- -::MMMM    |/
#              MM~:~ 00~:::::~ 00~:~MM
#         .. MMMMM::.00:::+:::.00::MMMMM ..
#               .MM::::: ._. :::::MM.
#                  MMMM;:::::;MMMM
#           -MM        MMMMMMM
#           ^  M+     MMMMMMMMM
#               MMMMMMM MM MM MM
#                    MM MM MM MM
#                    MM MM MM MM
#                 .~~MM~MM~MM~MM~~.
#              ~~~~MM:~MM~~~MM~:MM~~~~
#             ~~~~~~==~==~~~==~==~~~~~~
#              ~~~~~~==~==~==~==~~~~~~
#                  :~==~==~==~==~~

# %%
from github import Github
g = Github(_TOKEN)

g.get_rate_limit().core.raw_data
# Out:
# {'limit': 5000, 'used': 24, 'remaining': 4976, 'reset': 1712736884}

# %%
def init_dirs(root='.'):
    os.makedirs(osp.join(root, 'data'), exist_ok=True)
    os.makedirs(osp.join(root, 'data/repos'), exist_ok=True)

init_dirs(ROOT)

# %%
def get_url_repo(query_kw, page_no, stars_ub, item_per_page, lang):
      # %20 and + are all legal connectives between query words and properties
      # stars:<={stars}&sort=stars&order=desc
      url = f"https://api.github.com/search/repositories?q={query_kw}+language:{lang}+stars:<={stars_ub}&sort=stars&order=desc&page={page_no}&per_page={item_per_page}"
      print(f"request url: {url}")
      return url


def get_results(url, max_retry=5, req_every_k_secs=10):
      def _get(url):
            resp = requests.get(url, headers=HEADERS)
            if resp.status_code == 200:
                  txt = resp.content.decode()
                  return json.loads(txt)
            return None
      
      while max_retry>0:
            results = _get(url)
            if (results is not None) and (not results['incomplete_results']):
                  return results
            print(f'failed to get result from url! retry count: {max_retry}')
            time.sleep(req_every_k_secs)
            max_retry-=1
      return None

# %%
def sample(results, k=1):
    print(f"item count in this return: {len(results['items'])}")
    for item in results['items'][:k]:
        print("item name: {}, home_page: {}, stars: {}".format(item['full_name'], item['homepage'], item['stargazers_count']))

def save(results, out_path):
    with open(out_path, mode='w') as fp:
        json.dump(results['items'], indent=4, fp=fp)

def div_and_ceil(a, b):
    return a // b + int((a % b) != 0)

def get_lowest_star(items):
    return items[-1]['stargazers_count']

def process(url, out_path):
    results = None
    results = get_results(url)
    if results is not None:
        save(results, out_path)
    return results

def get_outpath(page_no):
    return osp.join(ROOT, f'data/res_{page_no}.json')

# %%
repo_query_kw = 'systemverilog'
lang = repo_query_kw

req_every_k_secs = 6
sample_every_k_pages = 5
stars_ub = 100000   # The upper bound of stars for query
item_per_page = 100
max_retrievable_item_limit = 1000
max_pages_per_search = div_and_ceil(max_retrievable_item_limit, item_per_page)

results = process(get_url_repo(repo_query_kw, 1, stars_ub, item_per_page, lang), out_path=get_outpath(1))
if results is not None:
    total_count = results['total_count']
    print(f"total queried count: {total_count}")
    sample(results, k=1)
    total_pages = div_and_ceil(total_count, item_per_page)
    time.sleep(req_every_k_secs)
# Out:
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=1&per_page=100
# total queried count: 1455
# item count in this return: 100
# item name: hdl-util/hdmi, home_page: https://purisa.me/blog/hdmi-released/, stars: 897

# %%
start = 2
for real_page_no in range(start, total_pages+1):
    print(f'On page: {real_page_no}')
    page_no = real_page_no % max_pages_per_search
    if page_no == 0:
        page_no = max_pages_per_search
        results = process(get_url_repo(repo_query_kw, page_no, stars_ub, item_per_page, lang), get_outpath(real_page_no))
        stars_ub = get_lowest_star(results['items'])
    else:
        results = process(get_url_repo(repo_query_kw, page_no, stars_ub, item_per_page, lang), get_outpath(real_page_no))
        # if star is not reducing, it means we have reached the long flatten part of the star curve
        # there is no way to ensure a stable order of repos at the moment:
        # see https://github.com/sourcegraph/sourcegraph/issues/2562
        # we have two choices thereafter:
        # 1. stop here
        # 2. continue:
        #   a. randomly sample at this star_count till no more new repo id arrives
        #   b. skip this star_count to the next one
        # here we choose to stop
        if get_lowest_star(results['items']) == stars_ub:
            break
    if real_page_no % sample_every_k_pages == 0:
        sample(results, k=1)
    time.sleep(3)
# Out:
# On page: 2
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=2&per_page=100
# On page: 3
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=3&per_page=100
# On page: 4
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=4&per_page=100
# On page: 5
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=5&per_page=100
# item count in this return: 100
# item name: quangphan2405/SystemVerilog, home_page: , stars: 1
# On page: 6
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=6&per_page=100
# On page: 7
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=7&per_page=100
# On page: 8
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=8&per_page=100
# On page: 9
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=9&per_page=100
# On page: 10
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=100000&sort=stars&order=desc&page=10&per_page=100
# item count in this return: 100
# item name: ChenJianJun520/AXI, home_page: None, stars: 0
# On page: 11
# request url: https://api.github.com/search/repositories?q=systemverilog+language:systemverilog+stars:<=0&sort=stars&order=desc&page=1&per_page=100

# %% [markdown]
# # filter repos by searching code inside repo with keywords 'property'

# %%
def load_and_save(data, out_path):
    full_data = []
    if osp.exists(out_path):
        with open(out_path, 'r') as fp:
            full_data = json.load(fp)
    full_data.extend(data)
    with open(out_path, 'w') as fp:
        json.dump(full_data, fp=fp, indent=4)

def get_url_code(query_kw, lang, repo):
    surfix = '{}+in:file+language:{}+repo:{}'.format(query_kw, lang, repo)
    return f"https://api.github.com/search/code?q={surfix}"

# %%
code_query_kw = 'property'

filenames = os.listdir('./data')
files = [osp.join('./data', f) for f in filenames if 'res_' in f]

# %%
for file_path in files:
    print(f'On file: {file_path}')
    with open(file_path, 'r') as fp:
        items = json.load(fp)

    filtered_repos = []
    startfrom = 0
    for i, item in enumerate(items):
        if i < startfrom:
            continue
        repo = item['html_url'].replace('https://github.com/', '')
        print(f'On No.{i}: {repo}')
        results = get_results(get_url_code(code_query_kw, lang, repo))
        if results['total_count'] != 0:
            filtered_repos.append({
                'repo_id': item['id'],
                'repo_name': item['full_name'],
                'download_url': item['clone_url'],
            })
        time.sleep(req_every_k_secs)
    load_and_save(filtered_repos, osp.join(ROOT, 'data/filtered_repos.json'))
# Out:
# On file: ./data\res_1.json
# On No.0: hdl-util/hdmi
# On No.1: pulp-platform/axi
# On No.2: trivialmips/nontrivial-mips
# On No.3: pulp-platform/common_cells
# On No.4: VerificationExcellence/SystemVerilogReference
# On No.5: WangXuan95/USTC-RVSoC
# On No.6: taichi-ishitani/tvip-axi
# On No.7: tymonx/logic
# On No.8: chipsalliance/sv-tests
# On No.9: veripool/verilog-mode
# failed to get result from url! retry count: 5
# On No.10: openhwgroup/core-v-mcu
# On No.11: subbdue/systemverilog.io
# On No.12: taichi-ishitani/tnoc
# On No.13: ijor/fx68k
# On No.14: GodelMachine/AHB2
# On No.15: loykylewong/FPGA-Application-Development-and-Simulation
# On No.16: trivialmips/TrivialMIPS
# On No.17: karthisugumar/CSE240D-Hierarchical_Mesh_NoC-Eyeriss_v2
# On No.18: StefanSredojevic/Deep-Neural-Network-Hardware-Accelerator
# failed to get result from url! retry count: 5
# On No.19: agalimberti/NoCRouter
# On No.20: VerificationExcellence/SystemVerilogAssertions
# On No.21: unixb0y/SystemVerilogSHA256
# On No.22: amiq-consulting/svaunit
# On No.23: ic-lab-duth/RISC-V-Vector
# On No.24: pulp-platform/pulp_soc
# On No.25: mmxsrup/axi4-interface
# On No.26: WangXuan95/FPGA-SATA-HBA
# On No.27: amiq-consulting/amiq_apb
# failed to get result from url! retry count: 5
# On No.28: pulp-platform/cheshire
# On No.29: BrianHGinc/BrianHG-DDR3-Controller
# On No.30: dpretet/axi-crossbar
# On No.31: hanysalah/Design-Pattern-in-SV
# On No.32: jerralph/riscv-vip
# On No.33: dshekhalev/FEC
# On No.34: ARC-Lab-UF/sv-tutorial
# On No.35: swetland/gateware
# On No.36: Siddhi-95/AHB-to-APB-Bridge-Verification
# On No.37: tymonx/virtio
# On No.38: pbing/FM_Radio
# On No.39: doswellf/combinator-uvm
# On No.40: johan92/fpga-hash-table
# On No.41: Superscalar-HIT-Core/Superscalar-HIT-Core-NSCSCC2020
# On No.42: muneeb-mbytes/SystemVerilog_Course
# On No.43: akzare/Async_FIFO_Verification
# On No.44: Harry-Chen/fpga-virtual-console
# On No.45: mikeroyal/Verilog-SystemVerilog-Guide
# On No.46: sgherbst/svreal
# On No.47: tenthousandfailures/systemverilog-design-patterns
# On No.48: zhouchuanrui/JSONinSV
# On No.49: pulp-platform/common_verification
# On No.50: mbgh/aes128-hdl
# On No.51: ben-marshall/croyde-riscv
# On No.52: nelsoncsc/sv_image
# On No.53: kaushalmodi/custom_uvm_report_server
# On No.54: uvmdebug/uvm_debug
# failed to get result from url! retry count: 5
# On No.55: gvekony/sv-1800-2012
# On No.56: cjdrake/AES
# On No.57: qleenju/PDPU
# On No.58: thomask77/verilog-sid-mos6581
# On No.59: Dmitriy0111/nanoFOX
# On No.60: esynr3z/usb20dev
# On No.61: luuvish/system-verilog-patterns
# On No.62: amichai-bd/riscv-multi-core-lotr
# On No.63: kaushalmodi/nim-systemverilog-dpic
# failed to get result from url! retry count: 5
# On No.64: Mochenx/sv_csv_parser
# On No.65: amiq-consulting/yamm
# On No.66: esynr3z/proto245
# On No.67: pezy-computing/pzbcm
# On No.68: pulp-platform/jtag_dpi
# On No.69: jiegec/verilog-format
# On No.70: esynr3z/axi_vip_demo
# On No.71: avashist003/SystemVerilog_Design_Verification
# On No.72: Aperture-Electronic/SystemVerilog-Bitmap-Library-AXI-Image-VIP
# failed to get result from url! retry count: 5
# On No.73: zhajio1988/ExtremeDV_UVM
# On No.74: isuckatdrifting/Gaia
# On No.75: davemuscle/sigma_delta_converters
# On No.76: yuravg/uvm_tb_cross_bar
# On No.77: Shehab-Naga/ddr5_phy
# On No.78: mxg/svx
# On No.79: taichi-ishitani/tvip-apb
# On No.80: sifferman/labs-with-cva6
# On No.81: pulp-platform/axi_node
# failed to get result from url! retry count: 5
# On No.82: taichi-ishitani/tue
# On No.83: ic-lab-duth/DRIM
# On No.84: abarajithan11/deepsocflow
# On No.85: merledu/azadi-soc
# On No.86: Dongtata2020/UVM_Verification_for_P2S_Data_Converter
# On No.87: zhouchuanrui/Cryptography-in-Systemverilog
# On No.88: forever-gk/AHB-SystemVerilog
# On No.89: bensampson5/libsv
# On No.90: hossein1387/pito_riscv
# failed to get result from url! retry count: 5
# On No.91: ic-lab-duth/DRIM-S
# On No.92: StanfordVLSI/dragonphy2
# On No.93: shehanmunasinghe/tinyGPU
# On No.94: tianrenz2/Single-Cycle-Processor
# On No.95: shady831213/jarvisuk
# On No.96: ttchisholm/10g-low-latency-ethernet
# On No.97: yuxuanZh/SystemVerilog
# On No.98: gokulbalagopal/Verification-of-FIFO-using-SystemVerilog
# On No.99: zhajio1988/YasaUvk
# failed to get result from url! retry count: 5
# On file: ./data\res_10.json
# On No.0: ChenJianJun520/AXI
# On No.1: Askotinderin/VL-Sorter
# On No.2: nil1g18/Frequency-measurer
# On No.3: sgahern2/simple_sv
# On No.4: henry-ns/Henrique_Martins_Ex02_SV
# On No.5: ezhysm/sv-design-library
# On No.6: emilijav-97/Verilog
# On No.7: vrstanchev/Verilog-Projects
# On No.8: marshray/svl_stuff
# failed to get result from url! retry count: 5
# On No.9: joachimcao/lab0
# On No.10: naftali10/Samll-SV-Projects
# On No.11: Heaton15/udemy-uvm
# On No.12: nisssal/uvml
# On No.13: ElectronicBatman/Generic-Mat-Mult
# On No.14: dasushi/blips-n-chips
# On No.15: Aimini/maips
# On No.16: nil1g18/Digital-Signal-Repeater-Phase-locked-Loop
# On No.17: ronniegertman/pacman
# failed to get result from url! retry count: 5
# On No.18: lazarvulic99/SystemVerilog-Verification---Register-functionalities
# On No.19: aaronferrucci/dcpu16-model-SystemVerilog
# On No.20: ggamb1t/Practice_Spring2020_SystemVerilog
# On No.21: zjed/SystemVerilog_DMA_Controller_Testbench
# On No.22: alpgurlee/FB-CPU-SystemVerilog-Testbench
# On No.23: henry-ns/Henrique_Martins_Ex01_MB_SV
# On No.24: LiuChenHsiung/test_sv
# On No.25: systemverilogstudio/training
# On No.26: jacklee023/logging
# failed to get result from url! retry count: 5
# On No.27: FeifanXuUF/Convert-basic-algorithm-to-systemverilog
# On No.28: 10611anil/Calculator_functional_hardware_verification_systemverilog
# On No.29: Skwoogey/SystemVerilog-GameOfLife
# On No.30: chrisdlg/simon_says_FPGA_SystemVerilog
# On No.31: ArslaanShamim/50_programs-of-RTL_systemverilog
# On No.32: victor-welter/EC6-PVLSI-SystemVerilog
# On No.33: tharinduSamare/Multicore_processor_SystemVerilog_design
# On No.34: chriswebbb/Testing_Circuits_Using_SystemVerilog
# On No.35: woodrowb96/systemverilog-fifo-and-uvm-testbench
# On No.36: iremsvn/digital-design-labs
# On No.37: pragya77/Memory-module-using-SystemVerilog
# On No.38: AlphanEker/SingleCycle-SystemVerilog-Model
# On No.39: Adeen317/100_DaysofRTL_SystemVerilog
# On No.40: sid-anand98/Synchronous-FIFO-in-SystemVerilog
# On No.41: ashfanvahora/Boolean-Function-using-SystemVerilog
# On No.42: tvsVLSI/MOD_12_COUNTER_SystemVerilog
# On No.43: hArtig4n/dynamic-cast-with-SystemVerilog
# On No.44: abhaysp2/ECE385-SystemVerilog-Code
# failed to get result from url! retry count: 5
# On No.45: Raghavi9860/Verification_of_ALU_using_systemverilog
# On No.46: lucasebs/LucasEmanuelSantos_Ex01_MB_SV
# On No.47: gencturkmert/Pipelined-Processor
# On No.48: y-kim/memtester-sv
# On No.49: jtsang02/Baccarat
# On No.50: madhu2000u/Matrix-Vector-Multiplier
# On No.51: linux4life798/JawBreakerAES
# On No.52: SplenDidShot/FPGA_SoC_Game_Deisgn
# On No.53: utkarshsarbahi1998/Intel_Quartus_Prime_SystemVerilog_Files
# failed to get result from url! retry count: 5
# On No.54: usmank11/Pong
# On No.55: sukruthivempati/USART
# On No.56: ChrisArreFall/PS-2_Controller
# On No.57: ArmanGhafarnia/RISC-V-multi-cycle-processor
# On No.58: nebhrajani-a/sfifo
# On No.59: AndersonNobrega/CircuitosIntegrados
# On No.60: sunbanett40/XOR-Decryptor
# On No.61: KennethWilke/sv-pulse-counter
# On No.62: lukewulf/floatingPointAddition
# failed to get result from url! retry count: 5
# On No.63: Dragon-Git/Design_Pattern
# On No.64: edjose2206/Codigo_SV
# On No.65: kkiningh/libkw
# On No.66: christinewoo/HammerFPGA
# On No.67: miura-katsuyoshi/thermometer
# On No.68: nil1g18/Booth-s-multiplier
# On No.69: chl218/Digital-Systems-Laboratory
# On No.70: runsler/sudoku
# On No.71: jfetkotto/SPISlave
# failed to get result from url! retry count: 5
# On No.72: qasimnaeem364/demos
# On No.73: ayanjdeka/SLC-3.2
# On No.74: sharanbr/assorted_verification
# On No.75: pawarsumeet81/Simulation-of-LLC-Cache-using-SystemVerilog
# On No.76: rgsouza/TelecomParistech-Reconfigurable-architectures-and-HDL-language-course
# On No.77: honeytung/ELEC402-FSM_Project
# On No.78: TyKeeling/hardware-sha256
# On No.79: DaveMcEwan/student-asvi
# On No.80: BW0ng/High-Speed-Arthmetic
# failed to get result from url! retry count: 5
# On No.81: melihtanriyakul/ALU-and-testbench-in-SystemVerilog
# On No.82: jo0012/8-Bit-CPU-in-SystemVerilog
# On No.83: ayush2350/Synchronous-FIFO-Verification-using-SystemVerilog
# On No.84: jpalicke/Single-Core-RISC-in-SystemVerilog
# On No.85: sumedhkr95/16-bit-FIR-filter-in-SystemVerilog
# On No.86: minabedwany/32_bits_enhanced_ALU_SystemVerilog
# On No.87: tylergithub/SHA-3-Permutation-Engine_SystemVerilog
# On No.88: gorkemnisanci96/SystemVerilogForVerificationPart1
# On No.89: Ashnfreeman/N-bit_graycode_binary_converter_systemverilog
# failed to get result from url! retry count: 5
# On No.90: Boulder1999/Verification-Using-SystemVerilog-From-Lab09-
# On No.91: medximun/SystemVerilog-for-Verification-Part-1-Fundamentals
# On No.92: louay-hesham/PipelinedMIPS
# On No.93: Hassan-Elseoudy/Mips-Pipelined
# On No.94: wswslzp/SAD_disparity
# On No.95: SpaghettiScritps/simple-FPGA-modules
# On No.96: SingularityKChen/RC6_sv
# On No.97: prabakaranvlsi/SyncFIFO
# On No.98: gchinna/eight-queens-sv
# failed to get result from url! retry count: 5
# On No.99: moriahgau/ECE385-Final-Project
# On file: ./data\res_11.json
# On No.0: hassyy/systemverilog-assertion
# On No.1: sdivcom/SystemVerilog
# On No.2: deterjan/FPGA-Tetris
# On No.3: MPSU/SV4DV
# On No.4: jay16udani/ECE745_LC3_Verification
# On No.5: JenniferZyf0220/Systola
# On No.6: vsandeepsekhar/verification
# On No.7: donev-stan/SystemVerilog
# failed to get result from url! retry count: 5
# On No.8: asicdv/systemverilog
# On No.9: parkjonguk/Systemverilog
# On No.10: abbasrsyedk/SystemVerilog
# On No.11: Vivek-Dave/SystemVerilog
# On No.12: sumedha1/systemVerilog
# On No.13: OnurErtunc/SystemVerilog
# On No.14: AntonyGeorgiadis/SystemVerilog
# On No.15: rm1096/SystemVerilog
# On No.16: AshishAttri/systemverilog
# On No.17: walberfa/SystemVerilog
# On No.18: Smitlea/SystemVerilog
# On No.19: sriyerg/systemverilog
# On No.20: DivyeshMakwana12599/SystemVerilog
# On No.21: 3820bilal/SystemVerilog
# On No.22: aunics/SystemVerilog
# On No.23: zha71186/Systemverilog
# On No.24: priyankp87/systemverilog
# On No.25: gsingla21/systemverilog
# failed to get result from url! retry count: 5
# On No.26: manasks/systemverilog
# On No.27: tukshetty/SystemVerilog
# On No.28: AlPrime2k1/SystemVerilog
# On No.29: nkulkarni78/SystemVerilog
# On No.30: milanlazic97/systemverilog
# On No.31: Rookie-cprime/Systemverilog
# On No.32: wa9035148/systemverilog
# On No.33: gaganminocha/systemverilog
# On No.34: salaheddinhetalani/SystemVerilog
# failed to get result from url! retry count: 5
# On No.35: swetharajagopalan17/SystemVerilog
# On No.36: canbozaci/SystemVerilog
# On No.37: G-uit-student/SystemVerilog
# On No.38: JuanMMonteros/SystemVerilog
# On No.39: wasim92007/systemverilog
# On No.40: aaronrjmanj/systemverilog
# On No.41: djgalati/Systemverilog
# On No.42: keerthirajan03/systemverilog
# On No.43: lee-coder/SystemVerilog
# failed to get result from url! retry count: 5
# On No.44: darshil24/SystemVerilog
# On No.45: sarahbrande/SystemVerilog
# On No.46: Louisredstone/SystemVerilog
# On No.47: sanjanachawla/SystemVerilog
# On No.48: joaosoaresaalm/SystemVerilog
# On No.49: mrdhindsa/SystemVerilog
# On No.50: debruynmonge/SystemVerilog
# On No.51: HappyChuckProgramming/SystemVerilog
# On No.52: rkasal/systemVerilog
# failed to get result from url! retry count: 5
# On No.53: MouVen/SystemVerilog
# On No.54: jardelymaris/SystemVerilog
# On No.55: UpendraSaiCH/SystemVerilog
# On No.56: abhishek-pwr/SystemVerilog
# On No.57: jwadehyun/SystemVerilog
# On No.58: ee19m047/systemVerilog
# On No.59: harshmomaya/SystemVerilog
# On No.60: whkkkkkkc/SystemVerilog
# On No.61: nithinbhargav007/SystemVerilog
# failed to get result from url! retry count: 5
# On No.62: nimaomidsajedi/SystemVerilog
# On No.63: sara-totah/SystemVerilog
# On No.64: tieovi/SystemVerilog
# On No.65: ian7aylor/SystemVerilog
# On No.66: soukalin96/SystemVerilog
# On No.67: bushbecky/SystemVerilog
# On No.68: eugenecc1/SystemVerilog
# On No.69: fightforit/systemverilog-tutorial
# On No.70: jeesonk/fpga_projects
# failed to get result from url! retry count: 5
# On No.71: amartinez10/systemverilogprojects
# On No.72: kanedayo/test_systemverilog
# On No.73: nguyencanhtrung/systemverilog_axis
# On No.74: tangshi706/systemverilog-learning
# On No.75: heidtn/systemverilog_modules
# On No.76: scott7950/systemverilog_practice
# On No.77: igormacedo/systemverilog-study
# On No.78: jiayi-wang98/UART
# On No.79: look4raghav/DPI-SV
# failed to get result from url! retry count: 5
# On No.80: amanchadha/systemverilog-examples
# On No.81: gustcar/uvm-systemverilog
# On No.82: humayunsiraj123/Systemverilog_OOP
# On No.83: ducnguyenSJSU/Verilog
# On No.84: youmin1017/sv-tetris
# On No.85: TonyHo722/systemverilog_study
# On No.86: plasma16/systemverilog_verification
# On No.87: kleiner-fisch/systemverilog-cache
# On No.88: KennethWilke/capi-systemverilog
# failed to get result from url! retry count: 5
# On No.89: bhyou/systemverilog_demo
# On No.90: versonforgit/learn-systemverilog
# On No.91: merajhasan88/jpegdecoder-systemverilog
# On No.92: MFaizan11/UART_Systemverilog
# On No.93: nimra471/systemverilog-practice
# On No.94: GreyZenki/cse_systemverilog
# On No.95: vaisup/Systemverilog_Examples
# On No.96: tfiwm/systemverilog_snippets
# On No.97: pvlkhm/verilog
# failed to get result from url! retry count: 5
# On No.98: DavidBaensch/FPGACore
# On No.99: sebsadface/sv
# On file: ./data\res_2.json
# On No.0: holdenQWER/systemverilog_design_pattern
# On No.1: nelsoncsc/FFT
# On No.2: KafCoppelia/uvm-mcdf
# On No.3: ljhsiun2/EllipticCurves_SystemVerilog
# On No.4: tudortimi/reflection
# On No.5: RoaLogic/ahb3lite_pkg
# On No.6: dpretet/svlogger
# failed to get result from url! retry count: 5
# On No.7: tudortimi/vpi
# On No.8: HITSZ-NSCSCC22/mycpu
# On No.9: snbk001/100DaysofRTL
# On No.10: msinger/iceboy
# On No.11: fcayci/sv-digital-design
# On No.12: celesteneary/sms
# On No.13: nathaliafab/Projeto_IH_RISC-V
# On No.14: jsloan256/dpll
# On No.15: tenthousandfailures/constraintlayering
# failed to get result from url! retry count: 5
# On No.16: imokanj/gpio_agent
# On No.17: alisemi/fpga-projects
# On No.18: cc-hook/sv_string
# On No.19: kitune-san/KFPC-XT
# On No.20: Suntrakanesh/System-Verilog-bootcamp
# On No.21: medalotte/SystemVerilog-UART
# On No.22: harpreetbhatia/sv_practice
# On No.23: WeiChungWu/UVM_UART_Example
# On No.24: zhiyb/SVNES
# On No.25: antoinemadec/uvm_code_gen
# On No.26: Freecellera/freecellera-uvm
# On No.27: WajahatRiaz/QuadSPI
# On No.28: sld-columbia/esp-caches
# On No.29: Aperture-Electronic/Realtime-Bicubic-16X-SuperResolution-IP
# On No.30: zstechly/systemverilog
# On No.31: rggen/rggen-sv-rtl
# On No.32: amichai-bd/rvc_asap
# On No.33: hellgate202/crc_calc
# failed to get result from url! retry count: 5
# On No.34: Rain92/FPGA-Mandelbrot
# On No.35: bwitherspoon/wiphy
# On No.36: taichi-ishitani/tbcm
# On No.37: go2uvm/sva_traces
# On No.38: amiq-consulting/cagt
# On No.39: WajahatRiaz/AHB-Lite-Protocol-Verification
# On No.40: semify-eda/go.debug
# On No.41: martinKindall/risc-v-single-cycle
# On No.42: Rain92/vga_interface
# failed to get result from url! retry count: 5
# On No.43: martinKindall/mips_cpu
# On No.44: eanchlia/NN_Network_On_Chip
# On No.45: flasonil/Serial-Multiplier
# On No.46: hdl-util/image-processing
# On No.47: riscv-verification/riscvISACOV
# On No.48: AbhishekTaur/System-Verilog-Practice
# On No.49: MPSU/APS-reborn
# On No.50: 0ctobyte/procyon
# On No.51: iammituraj/FIFOs
# failed to get result from url! retry count: 5
# On No.52: jnestor/SV_Examples
# On No.53: jchengX/MAC_BFM
# On No.54: adibis/uvmBasics
# On No.55: abdelrhman-oun/DDR5_PHY_WriteOperation
# On No.56: kang-0909/mips-cpu
# On No.57: enkerewpo/methane
# On No.58: dpretet/bster
# On No.59: adibis/alu_tb
# On No.60: kdurant/uvm_study
# failed to get result from url! retry count: 5
# On No.61: avashist003/FIFO_SystemVerilog_Assertion
# On No.62: JasonBrave/pci-edu
# On No.63: PedroHSCavalcante/uvm-phase-jumping
# On No.64: jomonkjoy/SV-for-Design
# On No.65: chenyangbing/Memory
# On No.66: chenyangbing/UVM-example
# On No.67: Hazem-ali/SystemVerilog-Codes
# On No.68: muhammedkocaoglu/SystemVerilog-Tutorials
# On No.69: chandanpalai/SystemVerilog-Assertions
# failed to get result from url! retry count: 5
# On No.70: dalance/svlint-action
# On No.71: anthonyabeo/digital_circuits
# On No.72: BrianHGinc/SystemVerilog-HDMI-encoder-serializer-PLL-generator
# On No.73: jeras/rp32
# On No.74: nelsoncsc/sv_math
# On No.75: ghosh17/DualCoreProcessor
# On No.76: JC-S/Karatsuba_multiplier_HDL
# On No.77: zwhexplorer/Spiking-Neural-Network-Accelerator-EE552-project
# On No.78: Pedro-Manoel/LOAC
# failed to get result from url! retry count: 5
# On No.79: GeorgeSangillo/ARM-Single-Cycle-Processor
# On No.80: smartfoxdata/aes128
# On No.81: AleksandarKostovic/Matrix-MAC-Unit
# On No.82: ChrisShakkour/RV32I-MAF-project
# On No.83: andrewandrepowell/System-Snake
# On No.84: suisuisi/SystemVerilog
# On No.85: aunics/AHB5
# On No.86: skudlur/cayde
# On No.87: theSergeyGusev/svReadWrite_pcap
# On No.88: yuxiang660/learning-systemVerilog
# On No.89: zli87/SystemVerilog_Coursework
# On No.90: erickahmed/iceberg
# On No.91: bchangip/NibblerCPU
# On No.92: Kitrinx/LLAPI
# On No.93: gotti/shrv32
# On No.94: edcote/uvmgen
# On No.95: AkeelMedina22/RISC-V-Pipelined-Processor
# On No.96: KafCoppelia/uvm-mcdf_v2
# failed to get result from url! retry count: 5
# On No.97: kbbuch/LC3-Verification
# On No.98: guanzetong/OoO_processor
# On No.99: ppujari24/SonyCellSPU
# On file: ./data\res_3.json
# On No.0: david-fong/Sudoku-SV
# On No.1: SamarSarda/AMBA-APB-I2C-Project
# On No.2: artemglukhov/FLOG_BFLOAT16
# On No.3: takah29/arm-cpu
# On No.4: freecores/aes_beh_model
# On No.5: yifax/RISC-V-PipeLine
# failed to get result from url! retry count: 5
# On No.6: mballance/sv_bfms
# On No.7: scott7950/SystemVerilog_TB
# On No.8: robfpga/weighted_round_robin
# On No.9: oliviercotte/Arbiter
# On No.10: chenyangbing/SystemVerilog
# On No.11: rubinsteina13/SV_I2S_RX_CORE
# On No.12: jchengX/AXI_DRIVER
# On No.13: jhy1000/systemverilog_assertion
# On No.14: dhaivat7/SystemVerilog_CalC
# On No.15: tom-urkin/SPI
# On No.16: Kenta11/simple_uart
# On No.17: BrianHGinc/SystemVerilog-TestBench-BPM-picture-generator
# On No.18: 1varuna/fifo_tb_uvm
# On No.19: milestone12/JSON.sv
# On No.20: amiq-consulting/amiq_dcr
# On No.21: gchinna/dynrama-sv
# On No.22: Zeldax64/arvi
# On No.23: zhang-stephen/ethernet_w5300
# failed to get result from url! retry count: 5
# On No.24: arokasprz100/HDL-Safe
# On No.25: QianfengClarkShen/easy_fifo
# On No.26: Petersoj/CompactRISC16
# On No.27: kitune-san/KF8259
# On No.28: kitune-san/KFMMC
# On No.29: jeras/riscv_asm_sv
# On No.30: uwesimm/uvm-indirect-registers
# On No.31: mriosrivas/HW-course-material
# On No.32: shin-yamashita/5th-AI-Edge-Contest
# On No.33: WasabiFan/apio-upduino-template
# On No.34: GabbedT/FIFO
# On No.35: msinger/dmg-sim
# On No.36: mehaltalukder/UART_UVM_Project
# On No.37: ppnipuna/Network_Switch
# On No.38: takatz28/FIFO-BIST
# On No.39: opengateware-modules/video-framebuffer
# On No.40: rggen/rggen-sv-ral
# On No.41: mateuspinto/simplified-mips-pipeline
# failed to get result from url! retry count: 5
# On No.42: IskXCr/CS202-CS214-Computer-Organization-Project
# On No.43: KelvinVale/uvm_sc_py_phase_jump
# On No.44: atmughrabi/AccelGraph
# On No.45: ourarash/SystemVerilogCSP
# On No.46: elegz/sv_code_samples
# On No.47: acmpesuecc/BareBones
# On No.48: AkshayXPatil/Design-verification
# On No.49: kruegz/cpu
# On No.50: squared-studio/SystemVerilog
# failed to get result from url! retry count: 5
# On No.51: appledore22/ALU_Verification_IP
# On No.52: seanluo1/FPGA-Fighting-Game
# On No.53: ShashankVM/generic_systemverilog_designs_library
# On No.54: Dimitrov2005/FIFO-testbench-with-systemVerilog
# On No.55: ciroceissler/sv_design_patterns
# On No.56: alinaivanovaoff/coding_style
# On No.57: victor-welter/EC4-ACD-SystemVerilog
# On No.58: z-e-r-0/Digital-piano-in-SystemVerilog
# On No.59: taichi-ishitani/sv_hackathon_2014
# failed to get result from url! retry count: 5
# On No.60: LimoJ/PolarCode
# On No.61: embeddedmoscow/HDL
# On No.62: tudortimi/prog_assert
# On No.63: antmicro/tl-ahb-bridge
# On No.64: engr-zahra/AHB-lite-Verification-in-SystemVerilog
# On No.65: aaronshappell/tage-predictor
# On No.66: PeterMonsson/lpcm-verilator
# On No.67: himingway/Parallel_Multiplier
# On No.68: segocago/CS223-Digital-Design-Highway-Racing
# failed to get result from url! retry count: 5
# On No.69: farshad112/ring_oscilator
# On No.70: bluecmd/sva-playground
# On No.71: pbing/dcf77_receiver
# On No.72: Electronic-and-Computer-Engineering/mic-1-hdl
# On No.73: mankelly/VerilogProjects
# On No.74: MuhammadMajiid/MIPS-Processor
# On No.75: kitsuneh/SVGameBoy
# On No.76: kitune-san/KFPS2KB
# On No.77: JA1TYE/iCEPIC
# failed to get result from url! retry count: 5
# On No.78: yalchinAlv/MarbleMazeGame
# On No.79: justinscottlee/Topaz-Geyser-RV32E
# On No.80: cquickstad/uvm_unit
# On No.81: mcai/Cozim
# On No.82: martinriis/Verilog-FastAdder
# On No.83: hdl-util/clock-domain-crossing
# On No.84: sickRanchez-c137/InferenceInFPGA
# On No.85: xshi1012/SingleCycleProcessor
# On No.86: bhaveshghantiwala/10-gigabit-ethernet-mac-verification
# failed to get result from url! retry count: 5
# On No.87: hakula139/MIPS-CPU
# On No.88: yuhei1horibe/PWM_module
# On No.89: SarahToscano/MIPS32
# On No.90: rubinsteina13/SV_CLARKE_TRANSFORMATION_CORES
# On No.91: m1a1x1/bloom-filter
# On No.92: iammituraj/debouncer
# On No.93: 0n1shi/fpga-mips
# On No.94: aakif-h/RISC-V-Processor-Design
# On No.95: kkiningh/asic-design
# failed to get result from url! retry count: 5
# On No.96: eneskeles/noctavia
# On No.97: nockieboy/YM2149_PSG_system
# On No.98: ZZJ34/sv_final_project
# On No.99: tom-urkin/I2C
# On file: ./data\res_4.json
# On No.0: Darksecond/TimeWave
# On No.1: NikolaF-95/RAM_VIP
# On No.2: GabbedT/UART-Controller
# On No.3: deepak1824/NN_Calculator_SOC_Design
# On No.4: AsFigo/pyslint
# failed to get result from url! retry count: 5
# On No.5: freecores/systemverilog-uart16550
# On No.6: jinz2014/SystemVerilog
# On No.7: hoangthinh2016/simple-mem-testbench-sv
# On No.8: amamory-verification/vfsd-utopia
# On No.9: s-okai/sv-math
# On No.10: seanpm2001/SNU_2D_ProgrammingTools_IDE_SystemVerilog
# On No.11: UndefeatedSunny/SystemVerilog
# On No.12: Shashvat300/SystemVerilog
# On No.13: darthsider/SystemVerilog
# failed to get result from url! retry count: 5
# On No.14: jnestor/systolic_pq
# On No.15: dbretwolfe/UARTsv
# On No.16: seanpm2001/Learn-SystemVerilog
# On No.17: JoyenBenitto/tiktaktoe_using_systemVerilog
# On No.18: jsagoe1/Verilog-SystemVerilog
# On No.19: 0xD503/SystemVerilog-Modules
# On No.20: NotZombieFood/MIPS-SystemVerilog
# On No.21: Sizhe-Zhang/HDC-SystemVerilog-Cadio
# On No.22: Elzawawy/mips-processor-simulator
# failed to get result from url! retry count: 5
# On No.23: zcold/prioritized_arbiter
# On No.24: Mehdi0xC/SystemVerilog-FixedPoint-Arithmetic
# On No.25: kristoforlovsky/asicde-SystemVerilog-visualization-test
# On No.26: antmicro/ahb-tl-bridge
# On No.27: medalotte/sync-FIFO
# On No.28: PedroHSCavalcante/env-mult-clk-domain
# On No.29: NickSica/RISC-V-CPU
# On No.30: Featherweight-IP/fwprotocol-defs
# On No.31: DigitalRabbit85/SvLibDR
# failed to get result from url! retry count: 5
# On No.32: nicolas-robin/nr6502
# On No.33: taichi-ishitani/rice
# On No.34: rajdasadia/Ethernet-Switch-with-Verification-Environment-SystemVerilog
# On No.35: Shihhaolin/verificatio-of-mux4-1-using-systemverilog
# On No.36: Ag48/sv_dpi
# On No.37: guillegil/sv-verification-example
# On No.38: chanum/uvm_verification
# On No.39: gkaratziolas/D1_Shift_Multiplier
# On No.40: hypernyan/modbus_rtu_slave_hdl
# failed to get result from url! retry count: 5
# On No.41: sgalal/DigitalClock
# On No.42: dhaivat7/RISC_CPU
# On No.43: yuya-isaka/hotate
# On No.44: vani2620/Custom-CPU
# On No.45: PassantSamirkh/SimpleAdderTestbench_SystemVerilog-with-and-without-classes
# On No.46: hdl-util/gray-code
# On No.47: kyle-sit/Floating-Point-Modules
# On No.48: abarajithan11/a-risc
# On No.49: kitune-san/KF8255
# failed to get result from url! retry count: 5
# On No.50: kinpoko/ktc32
# On No.51: dpretet/chacha20
# On No.52: tom-urkin/FIR-filter
# On No.53: ErickOF/VGA-Controller-FPGA
# On No.54: ytoml/cpu_playground
# On No.55: Viraldoshi1989/Verification_IP
# On No.56: kang-0909/digital-clock
# On No.57: zbnt/hardware
# On No.58: javacafe01/hash
# failed to get result from url! retry count: 5
# On No.59: jiru1997/design-and-verification-of-MCDF-phase3
# On No.60: suyashmahar/urisc
# On No.61: ZivFung/HDL_Module
# On No.62: lcbeams/DE10-Lite_Accelerometer
# On No.63: takatz28/RISCY-Processor
# On No.64: Abdul-muheet-ghani/UVM-Practice
# On No.65: tom-urkin/AMBA
# On No.66: WajahatRiaz/Simple-Memory-Verification
# On No.67: gvilardefarias/Hardware-Data-Structures
# On No.68: rubinsteina13/SV_DSM_CORE
# On No.69: mateuspinto/de2115-simple-mips-without-pipeline
# On No.70: mrLSD/fpga
# On No.71: Hong-Ming/FPGA-Oscilloscope
# On No.72: DJosueMM/GrayDecoder
# On No.73: akzare/TWireSerIntrfc
# On No.74: Geniussh/Bitcoin-Hash
# On No.75: GabbedT/Arithmetic-Circuits
# On No.76: dh73/uninterpreted_functions
# failed to get result from url! retry count: 5
# On No.77: alanmimms/kl10
# On No.78: ufukpalpas/Cellular-automata-game
# On No.79: mrRedSun/Simple-MIPS-Processor
# On No.80: JZJisawesome/JZJCoreF
# On No.81: MasterPlayer/axis_uart_bridge
# On No.82: PXVI/mips-pro-adam
# On No.83: snbk001/LIN-protocol
# On No.84: pConst/xilinx_max_power
# On No.85: Shihhaolin/Four-port-switch-
# On No.86: minjiexm/svlib_0.5
# On No.87: meiniKi/logIP
# On No.88: shubhv26/Special-processor-supporting-various-Pseudo-Random-Pattern-Generating-functionalities-PRPG
# On No.89: abdo1819/mips_single_cycle
# On No.90: ayengec/FPGA-Design-with-Systemverilog
# On No.91: wavelet-eda/reptilia
# On No.92: abdo1819/pipline_mips
# On No.93: medalotte/interleaved-sync-FIFO
# On No.94: eladawy1988/SystemVerilog
# On No.95: JuanSync7/SystemVerilog
# On No.96: abdullahmemisoglu/systemverilog
# On No.97: kirtikaran3/SystemVerilog
# On No.98: Voprzybyo/SystemVerilog
# On No.99: Sanket-Makkar/SystemVerilog
# On file: ./data\res_5.json
# On No.0: quangphan2405/SystemVerilog
# On No.1: vedantgarg28/SystemVerilog
# On No.2: chetha123/coverage_systemverilog
# On No.3: LispEngineer/systemverilog-hdmi
# failed to get result from url! retry count: 5
# On No.4: gchinna/sva
# On No.5: Teintetu/systemverilog-exercise
# On No.6: vyom-elan/System-Verilog
# On No.7: ma2mo10/study_systemverilog
# On No.8: amarnathmhn/Systemverilog_Assertions
# On No.9: chetha123/constraints_systemverilog
# On No.10: akshaypsoni/filehandling_systemverilog
# On No.11: hassyy/systemverilog-uvm
# On No.12: panaAHS/SystemVerilog-project
# failed to get result from url! retry count: 5
# On No.13: 0xArt/SystemVerilogUART
# On No.14: ameliaaltare/DES_SystemVerilog
# On No.15: TheShortDuck/synchronous_NoC_systemverilog
# On No.16: Elias-Rosales/MIPSVerification_SystemVerilog
# On No.17: tuanla93/SystemVerilog-UVM
# On No.18: abrahamjdn/Systemverilog-Verification-MIPS-Multicycle
# On No.19: clowak/Ramdas_SystemVerilogAssertions
# On No.20: minchaej/intro-to-systemverilog
# On No.21: nulface/SystemVerilog-VGA-controller
# failed to get result from url! retry count: 5
# On No.22: tannerpoling/SystemVerilog_Frogger
# On No.23: Imanm02/MipsCPU-SystemVerilog
# On No.24: mfkiwl/Configurable-Systolic-Systemverilog
# On No.25: Grapefruite/SHA256_SystemVerilog
# On No.26: XingJiangFelix/picoMIPS_SystemVerilog
# On No.27: kropotin4/SystemVerilog-examples
# On No.28: Linger0/sv
# On No.29: DavidWatkins/Chip8-SystemVerilog
# On No.30: Shihhaolin/Basic-Reference-of-Systemverilog
# failed to get result from url! retry count: 5
# On No.31: spacebiz24/SystemVerilog-Basics
# On No.32: clowak/Ramdas_SystemVerilogReference
# On No.33: everactive/volatile-regs
# On No.34: CaglayanDokme/SystemVerilogExercises
# On No.35: mish3albaiz/cache-simulation
# On No.36: oscc-ip/common
# On No.37: selvaruban-johnson/amba_apb_tb_II
# On No.38: kfinch333/alarm_clock
# On No.39: HighBaritone/ECE272FinalProject
# failed to get result from url! retry count: 5
# On No.40: flyskywalker/CAM
# On No.41: nelsoncsc/basicSV
# On No.42: leoP0/SystemVerylog
# On No.43: ghz-ws/fpga_sv
# On No.44: mitshine/OOPs-concept-in-SystemVerilog
# On No.45: ozlemcali/FB-CPU-SystemVerilog-Testbench
# On No.46: tonyalfred/ALU-Verification-using-SystemVerilog
# On No.47: mazrouei/SimpleSwitch_SystemVerilog_Verification
# On No.48: sadhanrudresh/My-experiment-with-SystemVerilog-
# failed to get result from url! retry count: 5
# On No.49: B-loved-ProFet/SPI-Module-in-SystemVerilog
# On No.50: oafonsoo/SPI-Module-in-SystemVerilog
# On No.51: anthonyarusso/systolic-array
# On No.52: Hong-Ming/Huffman-Codeing-IC
# On No.53: erihsu/xor_encrypt
# On No.54: nikoschatzi/Connect-Four
# On No.55: Cathuber/sv_fork_disable
# On No.56: neoblizz/CPU
# On No.57: louay-hesham/MultiCycleMIPS
# failed to get result from url! retry count: 5
# On No.58: hypernyan/ecc_vlg
# On No.59: brabect1/sv_handshake_comps
# On No.60: pbing/CORDIC
# On No.61: passant23/CNN-Convolutional-Neural-Network
# On No.62: RiordanPelayo/MIPS
# On No.63: gannoCal/JPEG-ish-SystemVerilog-Bistream-to-video
# On No.64: usman1515/SystemVerilog-for-Design-and-Verification
# On No.65: bigdot123456/vlogRun
# On No.66: furkanitap/8-Bit-Processor-in-SystemVerilog
# failed to get result from url! retry count: 5
# On No.67: Kashyappatel14/I2S_systemVerilog_Revision-1
# On No.68: Aceralon/CPU
# On No.69: jofrfu/PowerPC-SV
# On No.70: KennethWilke/shift-register
# On No.71: AlexeyShashkov/RSA
# On No.72: thampan/serial-fir-filter
# On No.73: NishadSaraf/Functional-Verification-Of-Fibonacci-Sequence-Generator
# On No.74: NeM-T/cpu
# On No.75: CristianG89/Design_Digital_Systems_2
# On No.76: asumagic/tinydumbcpu
# On No.77: npalmer5620/razor_cpu
# On No.78: AniketBadhan/Ethernet-packet-Loopback-design-verification
# On No.79: R-Rjn/System_Verilog
# On No.80: jpan127/MIPS-Architecture
# On No.81: abdulmannan1998/CS223
# On No.82: ChristianKouris/bitcoin-hash
# On No.83: skudlur/tic-tac-toe
# On No.84: zhang-stephen/hdlbits-sv-solutions
# failed to get result from url! retry count: 5
# On No.85: woodrowb96/RISCV-core-in-sytemverilog
# On No.86: asicguy/cnn
# On No.87: meagtan/cs-223-project
# On No.88: OMiD-Borzoei/RISC-V-MultiCycle
# On No.89: Shihhaolin/Verification-of-single-port-RAM-with-SystemVerilog-and-UVM-
# On No.90: mateuspinto/FPGA_SystemVerilog_MIPS_Pipeline-TP1-OC2-UFV
# On No.91: johan92/fpga-shared-memory
# On No.92: iExalt/BinaryCounter
# On No.93: AndrewHuynh97/Single_Cycle_Processor
# failed to get result from url! retry count: 5
# On No.94: ManuelonGithub/UART
# On No.95: nax47/ECE-211-Pong-Project
# On No.96: mjhborja/hello_world_uvm
# On No.97: h4ckerwu/ATMSwitch
# On No.98: ssayin/riscv32-cosim-model
# On No.99: yg2m19/cycle_computer
# On file: ./data\res_6.json
# On No.0: eliza0x/fost
# On No.1: estufa-cin-ufpe/RISC-V-Pipeline
# On No.2: agnicol88/Priority_4_to_1_Mux
# On No.3: pawarsumeet81/Design-and-Verification-of-DDR3-Memory-Controller-using-SystemVerilog
# On No.4: everactive/bathtub
# On No.5: Phzera/SVmodules
# On No.6: MuhammadHammad001/UART-Transmitter-using-SV
# On No.7: annwuhoo/tetris-sysverilog
# On No.8: shubhv26/Traffic-light-controller
# On No.9: jayantsakhare/ASYNCHRONOUS-FIFO-SVTB
# On No.10: fpozzana/Baugh-Wooley_multiplier
# On No.11: pestalella/hw_adder
# failed to get result from url! retry count: 5
# On No.12: jakesanggulee/ROP-Attack-Detector
# On No.13: roman-pogorelov/verlib
# On No.14: EmreAlabayMasterCourses/MEH173
# On No.15: saw235/sv_common_components
# On No.16: atrifex/Contra-SV
# On No.17: pbing/J1_WB
# On No.18: zeeshanrafique23/Buraq-mini
# On No.19: edwildson/MotorDePasso
# On No.20: dayzGoBy/I-LOVE-CACHE
# failed to get result from url! retry count: 5
# On No.21: Arnab035/RISC-Processor
# On No.22: Dmitriy0111/JTAG_debug
# On No.23: ShashankVM/overlapping-sequence-detector-1011-mealy-sv
# On No.24: OYounis/RTLblocks
# On No.25: ALittleBitFour/msgpack_sv
# On No.26: giacomovitangeli/light-hash-aes-sbox
# On No.27: iremkalkanli/RISC-V-Processor
# On No.28: midimaster21b/spi-bfm
# On No.29: mballance/std_protocol_if
# On No.30: jakemckenzie/Digital-System-Design
# On No.31: anttisalonen/veril
# On No.32: abrahamjdn/MIPS-Single-Cycle-Verification-using-SV.
# On No.33: mehaltalukder/ALU_UVM_Project
# On No.34: nekiicheb/axi_arbiter
# On No.35: shubhv26/Digital-Clock
# On No.36: WasabiFan/pipelined-rv32i-core
# On No.37: MattiaMartignoni/bfloat16_Exponential
# On No.38: LudwigCRON/platform
# On No.39: EzraCharles/Ezra_Charles_Digital_Systems_Verification
# On No.40: stineje/DES
# On No.41: joseljim/MIPS
# On No.42: XarkLabs/BenEaterSV
# On No.43: mballance/oc_wb_ip
# On No.44: Fahad-Habib/RISC-V-Single-Cycle-Processor
# On No.45: hahaha-sudo/simpleCPU
# On No.46: fl4shk/frost32_cpu
# On No.47: nikaemami/Latches-and-Flip-Flops
# failed to get result from url! retry count: 5
# On No.48: taichi-ishitani/tvip
# On No.49: ErickOF/CE4202-Oscilloscope-and-Digital-Filtering
# On No.50: shubhv26/Simple-Sloth-Game
# On No.51: KareemElozeiri/DigitalLogic
# On No.52: brendancarr34/MIPS-CPU
# On No.53: negative-seven/fpga_hdmi
# On No.54: munim-sah75/Design-and-Simulation-of-a-32-bit-RISC-V-Core-and-APB
# On No.55: everactive/svmetadata
# On No.56: XarkLabs/upduino-video
# failed to get result from url! retry count: 5
# On No.57: rekendahl/edaphic-studio-truss-project
# On No.58: hungbk99/SPI_APB
# On No.59: bching28/Arithmetic-Logic-Unit-ALU-
# On No.60: MuhammadHammad001/Multiplier-using-Russian-Peasent-algorithm
# On No.61: WBao93/Systolic-Array-2D-Convolution-Layer
# On No.62: daviddavo/tfg_poc_noc
# On No.63: iExalt/MD5
# On No.64: jcontrerasf/Team-ELO212
# On No.65: gggmmm/minmax
# failed to get result from url! retry count: 5
# On No.66: Lard4/RAT_CPU
# On No.67: soc-hub-fi/AnTiQ
# On No.68: TM90/VerilogModules
# On No.69: ErickOF/Single-Cycle-ARM-Processor-FPGA
# On No.70: knyuchen/interconnect_model
# On No.71: iammituraj/LIFO-Stack
# On No.72: midimaster21b/i2c-bfm
# On No.73: Sash-github-account/linked_list_rtl
# On No.74: iammituraj/gcd_calculator
# On No.75: felipesqra/LOAC
# On No.76: 34-Engineering/Virtex-HDL
# On No.77: josephkb87/VerilogBasics
# On No.78: akifejaz/HWConv2D
# On No.79: stephenry/qs
# On No.80: stps/puzzle-and-dragons
# On No.81: aaronghosh/Hamming-Code-in-System-Verilog-for-Error-Detection-and-Correction
# On No.82: aricneto/RISC-DCCCLXVII
# On No.83: sts08015/risc-v-lab
# failed to get result from url! retry count: 5
# On No.84: zeeshan0309/pseudo_random_sequence_generator
# On No.85: chad-cole/spec_sv
# On No.86: jadavs/FPGA_FlappyBird
# On No.87: AnastasiaMCunningham/SV-UVM-Sandbox
# On No.88: syedarafia13/RISCV-CORE-FPGA
# On No.89: tom-urkin/VGA-SRAM
# On No.90: nsailor/Feather
# On No.91: loserking/ECE-411
# On No.92: fl4shk/jolt80_cpu
# On No.93: dz1domin/BCDcounter
# On No.94: ekonwang/MIPS-CPU-yikun
# On No.95: astalstain/improV
# On No.96: rahulyesantharao/FPGA
# On No.97: Chandu4522/Ethernet_MAC_Verification
# On No.98: mfkiwl/RV32IMF-MicroGT_01
# On No.99: AllenHeartcore/ECE385_UIUC23sp
# On file: ./data\res_7.json
# On No.0: MarleyLobao/UVM_calculator
# On No.1: teekamkhandelwal/ENVIRONMENTAL-VERIFICATION-EXAMPLES
# failed to get result from url! retry count: 5
# On No.2: AllenHeartcore/ECE385_UIUC23sp
# On No.3: akki0084/AES-Rijndael-Algorithm-for-Encryption
# On No.4: PRADEEPCHANGAL/APB-Protocol-Verification-using-UVM
# On No.5: aryglins/RTL-CCMM
# On No.6: Marcotronics/100daysofRTL
# On No.7: KazukiChiyo/Modified-MIPS
# On No.8: gururavi/rtl
# On No.9: IskXCr/CS211-Project-Flappy-Bird
# On No.10: weisrc/nesv
# failed to get result from url! retry count: 5
# On No.11: Soham-coder/ROCC_based_neurosynapse
# On No.12: yateszi/pic2wave
# On No.13: mahdimoeini8102/DigitalSystems_IEEE754-2019
# On No.14: JoseDavidSS/TDD.CoffeeMachine-Prototype
# On No.15: skudlur/riscv-learn
# On No.16: sathviks/SytemVerilog
# On No.17: JoseDavidSS/TDD.Single-Cycle_Processor
# On No.18: RickFerreira/EstudosProjetoDeSistemasDigitais
# On No.19: akki0084/MIPS-based-32-bit-single-cycle-and-multi-cycle-microprocessor-design
# On No.20: shubhv26/MIPS-based-32-bit-single-cycle-and-multi-cycle-microprocessor-design
# On No.21: devanshi-jain/max_finder
# On No.22: SnrNotHere16/Asynchronous-FIFO
# On No.23: Christopher-Daniels/Lunar-Lander
# On No.24: karthik-0398/fpmultiplier
# On No.25: hassyy/systemverilog-assertion
# On No.26: sdivcom/SystemVerilog
# On No.27: deterjan/FPGA-Tetris
# On No.28: MPSU/SV4DV
# failed to get result from url! retry count: 5
# On No.29: jay16udani/ECE745_LC3_Verification
# On No.30: JenniferZyf0220/Systola
# On No.31: vsandeepsekhar/verification
# On No.32: donev-stan/SystemVerilog
# On No.33: asicdv/systemverilog
# On No.34: parkjonguk/Systemverilog
# On No.35: abbasrsyedk/SystemVerilog
# On No.36: Vivek-Dave/SystemVerilog
# On No.37: sumedha1/systemVerilog
# failed to get result from url! retry count: 5
# On No.38: OnurErtunc/SystemVerilog
# On No.39: AntonyGeorgiadis/SystemVerilog
# On No.40: rm1096/SystemVerilog
# On No.41: AshishAttri/systemverilog
# On No.42: walberfa/SystemVerilog
# On No.43: Smitlea/SystemVerilog
# On No.44: sriyerg/systemverilog
# On No.45: DivyeshMakwana12599/SystemVerilog
# On No.46: 3820bilal/SystemVerilog
# failed to get result from url! retry count: 5
# On No.47: aunics/SystemVerilog
# On No.48: zha71186/Systemverilog
# On No.49: priyankp87/systemverilog
# On No.50: gsingla21/systemverilog
# On No.51: milanlazic97/systemverilog
# On No.52: Rookie-cprime/Systemverilog
# On No.53: wa9035148/systemverilog
# On No.54: gaganminocha/systemverilog
# On No.55: manasks/systemverilog
# On No.56: tukshetty/SystemVerilog
# On No.57: AlPrime2k1/SystemVerilog
# On No.58: nkulkarni78/SystemVerilog
# On No.59: aaronrjmanj/systemverilog
# On No.60: wasim92007/systemverilog
# On No.61: djgalati/Systemverilog
# On No.62: salaheddinhetalani/SystemVerilog
# On No.63: swetharajagopalan17/SystemVerilog
# On No.64: canbozaci/SystemVerilog
# failed to get result from url! retry count: 5
# On No.65: G-uit-student/SystemVerilog
# On No.66: JuanMMonteros/SystemVerilog
# On No.67: keerthirajan03/systemverilog
# On No.68: joaosoaresaalm/SystemVerilog
# On No.69: mrdhindsa/SystemVerilog
# On No.70: debruynmonge/SystemVerilog
# On No.71: HappyChuckProgramming/SystemVerilog
# On No.72: rkasal/systemVerilog
# On No.73: lee-coder/SystemVerilog
# failed to get result from url! retry count: 5
# On No.74: darshil24/SystemVerilog
# On No.75: Louisredstone/SystemVerilog
# On No.76: sarahbrande/SystemVerilog
# On No.77: sanjanachawla/SystemVerilog
# On No.78: MouVen/SystemVerilog
# On No.79: jwadehyun/SystemVerilog
# On No.80: ee19m047/systemVerilog
# On No.81: jardelymaris/SystemVerilog
# On No.82: UpendraSaiCH/SystemVerilog
# failed to get result from url! retry count: 5
# On No.83: abhishek-pwr/SystemVerilog
# On No.84: nimaomidsajedi/SystemVerilog
# On No.85: sara-totah/SystemVerilog
# On No.86: harshmomaya/SystemVerilog
# On No.87: whkkkkkkc/SystemVerilog
# On No.88: nithinbhargav007/SystemVerilog
# On No.89: tieovi/SystemVerilog
# On No.90: ian7aylor/SystemVerilog
# On No.91: soukalin96/SystemVerilog
# failed to get result from url! retry count: 5
# On No.92: bushbecky/SystemVerilog
# On No.93: eugenecc1/SystemVerilog
# On No.94: fightforit/systemverilog-tutorial
# On No.95: jeesonk/fpga_projects
# On No.96: amartinez10/systemverilogprojects
# On No.97: kanedayo/test_systemverilog
# On No.98: nguyencanhtrung/systemverilog_axis
# On No.99: tangshi706/systemverilog-learning
# On file: ./data\res_8.json
# On No.0: heidtn/systemverilog_modules
# failed to get result from url! retry count: 5
# On No.1: scott7950/systemverilog_practice
# On No.2: jiayi-wang98/UART
# On No.3: look4raghav/DPI-SV
# On No.4: igormacedo/systemverilog-study
# On No.5: amanchadha/systemverilog-examples
# On No.6: gustcar/uvm-systemverilog
# On No.7: humayunsiraj123/Systemverilog_OOP
# On No.8: plasma16/systemverilog_verification
# On No.9: kleiner-fisch/systemverilog-cache
# failed to get result from url! retry count: 5
# On No.10: ducnguyenSJSU/Verilog
# On No.11: TonyHo722/systemverilog_study
# On No.12: youmin1017/sv-tetris
# On No.13: KennethWilke/capi-systemverilog
# On No.14: bhyou/systemverilog_demo
# On No.15: versonforgit/learn-systemverilog
# On No.16: merajhasan88/jpegdecoder-systemverilog
# On No.17: MFaizan11/UART_Systemverilog
# On No.18: vaisup/Systemverilog_Examples
# On No.19: tfiwm/systemverilog_snippets
# On No.20: pvlkhm/verilog
# On No.21: nimra471/systemverilog-practice
# On No.22: GreyZenki/cse_systemverilog
# On No.23: DavidBaensch/FPGACore
# On No.24: sebsadface/sv
# On No.25: SergioJJ/systemverilog-babysteps
# On No.26: H-S-S-11/miscellaneous-systemverilog
# On No.27: krunalbadlani/systemverilog_projects
# failed to get result from url! retry count: 5
# On No.28: saipra99/sai_systemverilog
# On No.29: rag1404/systemverilog_coverage
# On No.30: adnanashraf17501/Systemverilog-Bootcamp
# On No.31: Chico0212/Systemverilog_PSD
# On No.32: nguyencanhtrung/systemverilog-common
# On No.33: eduardohenriquearnold/myCPU
# On No.34: mfbsouza/MipsCPU
# On No.35: dirkxie/SystemVerilogSnippets
# On No.36: dpc525/SystemVerilog-Gotcha
# failed to get result from url! retry count: 5
# On No.37: Prekshita/SystemVerilog-Code
# On No.38: youhanamikhaiel/Pipeline-Processor-using-Systemverilog
# On No.39: MikhailKardash/SystemVerilog_Code
# On No.40: nefelimet/SystemVerilog-project
# On No.41: sarawiRTLDV/SystemVerilog-for-Verification
# On No.42: Maleeshas/SystemVerilogEx
# On No.43: Carlos12001/nand3_systemverilog
# On No.44: aknahin/ReversibleGates-SystemVerilog
# On No.45: braamBeresford/systemVerilogPong
# failed to get result from url! retry count: 5
# On No.46: chandanpalai/SystemVerilog-Basics
# On No.47: prajshet/SystemVerilog-projects
# On No.48: DevCode-C/SystemVerilog_Class
# On No.49: EStrugar/systemVerilogCPU
# On No.50: supreetgulavani/SystemVerilog_Projects
# On No.51: Yeahoon-Kim/CPU_SystemVerilog
# On No.52: bushbecky/Verilog-SystemVerilog-Guide
# On No.53: TianfengChen/SystemVerilog_notecode
# On No.54: franklinthony/integrated-circuits-systemverilog
# failed to get result from url! retry count: 5
# On No.55: LFzhaoyue123/SystemVerilog_Lab
# On No.56: cturgeon/SystemVerilogProject
# On No.57: AkisParousis/Writing_SystemVerilog
# On No.58: AndersonLLeite/ULA-em-SystemVerilog
# On No.59: HardGraphite/SystemVerilogPlayground
# On No.60: zhouxinyu0723/SystemVerilog_for_verification
# On No.61: joonjae/UVM-SystemVerilog
# On No.62: DaniJ2032/Projects-in-SystemVerilog
# On No.63: gaochangw/SystemVerilog_Practice
# On No.64: anshb24/SystemVerilog-Fundamentals
# On No.65: Zclaussen/SystemVerilog_Testbenches
# On No.66: sharvil111/aes128_systemverilog
# On No.67: Philngtn/Labs_systemVerilog
# On No.68: deoregaurav92/SystemVerilog_Coding_Practice
# On No.69: s-griffith/Simulation_1-SystemVerilog
# On No.70: ahmedatef935/AES-Verification-SystemVerilog
# On No.71: ahmedatef935/Mips-Verification-SystemVerilog
# On No.72: dsellerbrock/SystemVerilog_Prisoners
# failed to get result from url! retry count: 5
# On No.73: zkabyken/Basic-SystemVerilog-Processor
# On No.74: AlexandrosPanag/My_SystemVerilog_Projects
# On No.75: nguyencanhtrung/SystemVerilog-Practice
# On No.76: ZHOUJiemin/systemverilog-tb-framework
# On No.77: Kocha/systemverilog-report-package
# On No.78: himingway/SystemVerilog-Class-Lab
# On No.79: pranithbottu/SuperMario_SystemVerilog
# On No.80: Manoj3050/SystemVerilogPongGame
# On No.81: toms74209200/systemverilog_package_sample
# On No.82: chriswebbb/Microprocessor_Design_SystemVerilog
# On No.83: andmiele/SystemVerilogUtils
# On No.84: jmcandido/Codigos-SystemVerilog
# On No.85: axyrai/fullAdder_systemVerilog
# On No.86: brady-aiello/AES_in_SystemVerilog
# On No.87: jan-polivka/SystemVerilogStudy
# On No.88: ignperez-udec/CeNN-SystemVerilog
# On No.89: UandersonSilva/VGA_Controller_SystemVerilog
# On No.90: kernsimon98/SystemVerilog_FlappyBird
# failed to get result from url! retry count: 5
# On No.91: pragya77/Adder-design-SystemVerilog
# On No.92: UandersonSilva/UART_controller_SystemVerilog
# On No.93: P-coryan/SystemVerilogModules
# On No.94: kanuar/systemverilog_mux2-1
# On No.95: asimkhan8107/SystemVerilog_30DAYS
# On No.96: laoleee/Learn_SystemVerilog
# On No.97: stultusverus/SystemVerilog-Practices
# On No.98: IasonC/SystemVerilogCircuitDesign
# On No.99: dwiti9494/Verilog_SystemVerilog
# failed to get result from url! retry count: 5
# On file: ./data\res_9.json
# On No.0: stultusverus/SystemVerilog-Practices
# On No.1: IasonC/SystemVerilogCircuitDesign
# On No.2: dwiti9494/Verilog_SystemVerilog
# On No.3: talshamira/Simulation_1-SystemVerilog
# On No.4: sota5460/SystemVerilog_Tutorial
# On No.5: srsapireddy/SystemVerilog-Verification-Files
# On No.6: Nikhilaraghuram/SystemVerilog_Test
# On No.7: kanuar/systemverilog_mux8-1
# On No.8: avdheshgarodia/chip8-systemverilog
# On No.9: tsmoffat/SystemVerilogLabs
# On No.10: ukorat/SystemVerilog-Practice
# On No.11: Zottel/max7219-systemverilog-driver
# On No.12: CenkerAkan/SystemVerilog-Simple-MIPS
# On No.13: aqweszxcd/HammingCode_SystemVerilog
# On No.14: thinhngo11/Beyond-SystemVerilog-Classes
# On No.15: hamimulchowdhury/Systemverilog-code-practice
# On No.16: Alen302/SystemVerilog-for-HDLBits
# On No.17: jkennerly/simple-processor-systemverilog
# failed to get result from url! retry count: 5
# On No.18: Zclaussen/SystemVerilog_Timing_Optimization
# On No.19: SemiFront/SystemVerilog_SF
# On No.20: kanuar/systemverilog_mux4-1
# On No.21: UandersonSilva/BIP2_SystemVerilog
# On No.22: has58/perceptron_systemVerilog
# On No.23: ziqiangt/systemverilog-design_patterns
# On No.24: SeboThaGawd/SPI_SystemVerilog
# On No.25: woodrowb96/systemverilog-alu-and-testbench
# On No.26: SLawson/CAH_SystemVerilogSimulation
# failed to get result from url! retry count: 5
# On No.27: cameronnapoli/SystemVerilog-Pipelined-Processor
# On No.28: JonathanHonrada/Function_Generator_SystemVerilog
# On No.29: wilson07code/SystemVerilog_Lab
# On No.30: wangyipengw1p/Verilog-SystemVerilog-Xamples
# On No.31: sarpuser/SystemVerilog-Projects
# On No.32: luophoe/SystemVerilog-projects
# On No.33: kanuar/systemverilog_fulladder_with_ripplecarry
# On No.34: dhairyaagrawal/pipeline
# On No.35: KyleJosling/FPGA_modules
# failed to get result from url! retry count: 5
# On No.36: mec391/system_verilog_practice
# On No.37: AmirEfi/Decoder3x8-in-SystemVerilog
# On No.38: kencycheng/riscv_instruction_sv
# On No.39: nadaved1/SystemVerilog-Examples
# On No.40: rgliu/SystemVerilog-Samples
# On No.41: JoseK21/ALU_SystemVerilog
# On No.42: Z4R1Z/Cellular-Automata-SystemVerilog
# On No.43: suyash-20/SystemVerilog_repo
# On No.44: Patrickshiny/systemVerilogFiles
# failed to get result from url! retry count: 5
# On No.45: Andreu-Lechuga/SystemVerilog-HDL
# On No.46: olivamadrigal/DFT-in-SystemVerilog
# On No.47: AMAV26/-SystemVerilog-projects
# On No.48: dinalg/Tetris-SystemVerilog
# On No.49: masonJamesWheeler/Verilog-SystemVerilog
# On No.50: rbride/SystemVerilog_Practice_Problems
# On No.51: cjblocker/dvi_controller
# On No.52: bansil-vaghasiya/Design-and-verification-of-16-bit-64-KB-memory
# On No.53: uki-a/ibex_alu_custom
# failed to get result from url! retry count: 5
# On No.54: VictorHerbert/DigitalCores
# On No.55: coderky/SystemVerilog_chp11
# On No.56: richardojo12/Verilog-SystemVerilog-Projects
# On No.57: mandebi/SystemVerilog_Examples
# On No.58: FelixH316/SystemVerilog_AGC_2021
# On No.59: AlphanEker/Pipelined-SystemVerilog-Model
# On No.60: MarkReedZ/SystemVerilogTutorial
# On No.61: Ambika14-3/AHB-Protocol-SystemVerilog
# On No.62: keganpremuda/SystemVerilogMicroprocessor
# failed to get result from url! retry count: 5
# On No.63: minabedwany/Micro_Processor_SystemVerilog
# On No.64: RecepSaid/SystemVerilog-Examples
# On No.65: du6293/single_cycle_processor_systemverilog
# On No.66: jhladik/chu_systemverilog_exercises
# On No.67: wormyrocks/systemverilog-yosys-test
# On No.68: GeorgeOnwubuya/Reaction_Timer_SystemVerilog
# On No.69: sunbanett40/SystemVerilog-Programming
# On No.70: ErikPihl/Microcontroller-SystemVerilog
# On No.71: gabomora2200/systemVerilogPractice
# failed to get result from url! retry count: 5
# On No.72: hankhsu1996/vscode-better-systemverilog-syntax
# On No.73: Bouer/shifter_SystemVerilog
# On No.74: hp22-ela21/Mikrodator-SystemVerilog
# On No.75: mariosplen/SystemVerilog-UNI-LAB
# On No.76: tiliosys/Vermicel-CPU-SystemVerilog
# On No.77: Maturihacks/SystemVerilog_Lab_8
# On No.78: neoH/ASVE
# On No.79: Askartos/openPwm
# On No.80: SonNeyugn/uvm_practice
# On No.81: damlasu/FB-CPU-SystemVerilog-Testbench
# On No.82: CiceraRodrigues/Cicera_Ex01_MB_SV
# On No.83: igoral5/soda_machine
# On No.84: Fernsicles/FPGA-calc
# On No.85: rohith2h2/100_days_of_rtl_design
# On No.86: csnewman/juna
# On No.87: muaadh-hasan/Computer-Architecture-and-Organization
# On No.88: duongnghiephuy/processor1
# On No.89: eldesh/uvm_study
# failed to get result from url! retry count: 5
# On No.90: Haxrox/HaxElevator
# On No.91: aignacio/bus_arch_sv_pkg
# On No.92: ctrunkett/LogicAnalyzer
# On No.93: kfinch333/finite_state_machine
# On No.94: kfinch333/Microprocessor
# On No.95: hiimkimchi/Verilog-HDL-Lectures
# On No.96: filipeferibeiro/SHA-1
# On No.97: douglasnickson/DouglasNickson_Ex01_MB_SV
# On No.98: NotZombieFood/TempAverage
# failed to get result from url! retry count: 5
# On No.99: muzicarski/HDL

# %% [markdown]
# # download all repos by git clone or wget

# %%
def clone_repos(repos):
    def _git(*args):
        return subprocess.check_call(['git'] + list(args))
    for repo in repos:
        clone_url = repo['download_url']
        ret = _git("clone", clone_url)

def download_repos(repos, out_dir):
    for i, repo in enumerate(repos):
        print(f"On No.{i} repo: {repo}")
        url = repo['download_url']
        download_url = url[:len(url) - 4] + "/archive/refs/heads/master.zip"
        file_name =  repo['repo_name'].replace("/", "#") + '.zip'
        try:
            wget.download(download_url, out=osp.join(out_dir, file_name))
        except Exception as e:
            print("Could not download file {}".format(file_name))
            print(e)

# %%
with open("./data/filtered_repos.json", mode='r') as fp:
    repos = json.load(fp)

# %%
download_repos(repos, out_dir=osp.join(ROOT, 'data/repos'))
# Out:
# On No.0 repo: {'repo_id': 129229399, 'repo_name': 'pulp-platform/axi', 'download_url': 'https://github.com/pulp-platform/axi.git'}
# On No.1 repo: {'repo_id': 171665435, 'repo_name': 'trivialmips/nontrivial-mips', 'download_url': 'https://github.com/trivialmips/nontrivial-mips.git'}
# On No.2 repo: {'repo_id': 118764818, 'repo_name': 'pulp-platform/common_cells', 'download_url': 'https://github.com/pulp-platform/common_cells.git'}
# On No.3 repo: {'repo_id': 19295560, 'repo_name': 'VerificationExcellence/SystemVerilogReference', 'download_url': 'https://github.com/VerificationExcellence/SystemVerilogReference.git'}
# On No.4 repo: {'repo_id': 108771045, 'repo_name': 'tymonx/logic', 'download_url': 'https://github.com/tymonx/logic.git'}
# On No.5 repo: {'repo_id': 201299456, 'repo_name': 'chipsalliance/sv-tests', 'download_url': 'https://github.com/chipsalliance/sv-tests.git'}
# On No.6 repo: {'repo_id': 8392762, 'repo_name': 'veripool/verilog-mode', 'download_url': 'https://github.com/veripool/verilog-mode.git'}
# On No.7 repo: {'repo_id': 274802727, 'repo_name': 'openhwgroup/core-v-mcu', 'download_url': 'https://github.com/openhwgroup/core-v-mcu.git'}
# On No.8 repo: {'repo_id': 114001819, 'repo_name': 'taichi-ishitani/tnoc', 'download_url': 'https://github.com/taichi-ishitani/tnoc.git'}
# On No.9 repo: {'repo_id': 62000083, 'repo_name': 'GodelMachine/AHB2', 'download_url': 'https://github.com/GodelMachine/AHB2.git'}
# On No.10 repo: {'repo_id': 21086331, 'repo_name': 'VerificationExcellence/SystemVerilogAssertions', 'download_url': 'https://github.com/VerificationExcellence/SystemVerilogAssertions.git'}
# On No.11 repo: {'repo_id': 34787526, 'repo_name': 'amiq-consulting/svaunit', 'download_url': 'https://github.com/amiq-consulting/svaunit.git'}
# On No.12 repo: {'repo_id': 236462808, 'repo_name': 'ic-lab-duth/RISC-V-Vector', 'download_url': 'https://github.com/ic-lab-duth/RISC-V-Vector.git'}
# On No.13 repo: {'repo_id': 120769627, 'repo_name': 'pulp-platform/pulp_soc', 'download_url': 'https://github.com/pulp-platform/pulp_soc.git'}
# On No.14 repo: {'repo_id': 30076555, 'repo_name': 'amiq-consulting/amiq_apb', 'download_url': 'https://github.com/amiq-consulting/amiq_apb.git'}
# On No.15 repo: {'repo_id': 437053467, 'repo_name': 'ARC-Lab-UF/sv-tutorial', 'download_url': 'https://github.com/ARC-Lab-UF/sv-tutorial.git'}
# On No.16 repo: {'repo_id': 464943029, 'repo_name': 'Siddhi-95/AHB-to-APB-Bridge-Verification', 'download_url': 'https://github.com/Siddhi-95/AHB-to-APB-Bridge-Verification.git'}
# On No.17 repo: {'repo_id': 18693562, 'repo_name': 'doswellf/combinator-uvm', 'download_url': 'https://github.com/doswellf/combinator-uvm.git'}
# On No.18 repo: {'repo_id': 40177831, 'repo_name': 'johan92/fpga-hash-table', 'download_url': 'https://github.com/johan92/fpga-hash-table.git'}
# On No.19 repo: {'repo_id': 509037539, 'repo_name': 'muneeb-mbytes/SystemVerilog_Course', 'download_url': 'https://github.com/muneeb-mbytes/SystemVerilog_Course.git'}
# On No.20 repo: {'repo_id': 110600628, 'repo_name': 'akzare/Async_FIFO_Verification', 'download_url': 'https://github.com/akzare/Async_FIFO_Verification.git'}
# On No.21 repo: {'repo_id': 72968977, 'repo_name': 'uvmdebug/uvm_debug', 'download_url': 'https://github.com/uvmdebug/uvm_debug.git'}
# On No.22 repo: {'repo_id': 122607123, 'repo_name': 'gvekony/sv-1800-2012', 'download_url': 'https://github.com/gvekony/sv-1800-2012.git'}
# On No.23 repo: {'repo_id': 158221925, 'repo_name': 'Dmitriy0111/nanoFOX', 'download_url': 'https://github.com/Dmitriy0111/nanoFOX.git'}
# On No.24 repo: {'repo_id': 62645248, 'repo_name': 'amiq-consulting/yamm', 'download_url': 'https://github.com/amiq-consulting/yamm.git'}
# On No.25 repo: {'repo_id': 579842080, 'repo_name': 'pezy-computing/pzbcm', 'download_url': 'https://github.com/pezy-computing/pzbcm.git'}
# On No.26 repo: {'repo_id': 361092259, 'repo_name': 'esynr3z/axi_vip_demo', 'download_url': 'https://github.com/esynr3z/axi_vip_demo.git'}
# On No.27 repo: {'repo_id': 513341931, 'repo_name': 'avashist003/SystemVerilog_Design_Verification', 'download_url': 'https://github.com/avashist003/SystemVerilog_Design_Verification.git'}
# On No.28 repo: {'repo_id': 258239573, 'repo_name': 'zhajio1988/ExtremeDV_UVM', 'download_url': 'https://github.com/zhajio1988/ExtremeDV_UVM.git'}
# On No.29 repo: {'repo_id': 345558394, 'repo_name': 'ic-lab-duth/DRIM', 'download_url': 'https://github.com/ic-lab-duth/DRIM.git'}
# On No.30 repo: {'repo_id': 400485607, 'repo_name': 'merledu/azadi-soc', 'download_url': 'https://github.com/merledu/azadi-soc.git'}
# On No.31 repo: {'repo_id': 345948930, 'repo_name': 'ic-lab-duth/DRIM-S', 'download_url': 'https://github.com/ic-lab-duth/DRIM-S.git'}
# On No.32 repo: {'repo_id': 259401546, 'repo_name': 'StanfordVLSI/dragonphy2', 'download_url': 'https://github.com/StanfordVLSI/dragonphy2.git'}
# On No.33 repo: {'repo_id': 93367626, 'repo_name': 'jay16udani/ECE745_LC3_Verification', 'download_url': 'https://github.com/jay16udani/ECE745_LC3_Verification.git'}
# On No.34 repo: {'repo_id': 359465744, 'repo_name': 'Vivek-Dave/SystemVerilog', 'download_url': 'https://github.com/Vivek-Dave/SystemVerilog.git'}
# On No.35 repo: {'repo_id': 644086168, 'repo_name': 'AlPrime2k1/SystemVerilog', 'download_url': 'https://github.com/AlPrime2k1/SystemVerilog.git'}
# On No.36 repo: {'repo_id': 396984723, 'repo_name': 'msinger/iceboy', 'download_url': 'https://github.com/msinger/iceboy.git'}
# On No.37 repo: {'repo_id': 408514112, 'repo_name': 'Suntrakanesh/System-Verilog-bootcamp', 'download_url': 'https://github.com/Suntrakanesh/System-Verilog-bootcamp.git'}
# On No.38 repo: {'repo_id': 51796839, 'repo_name': 'harpreetbhatia/sv_practice', 'download_url': 'https://github.com/harpreetbhatia/sv_practice.git'}
# On No.39 repo: {'repo_id': 29715691, 'repo_name': 'Freecellera/freecellera-uvm', 'download_url': 'https://github.com/Freecellera/freecellera-uvm.git'}
# On No.40 repo: {'repo_id': 197411172, 'repo_name': 'rggen/rggen-sv-rtl', 'download_url': 'https://github.com/rggen/rggen-sv-rtl.git'}
# On No.41 repo: {'repo_id': 384764302, 'repo_name': 'Rain92/FPGA-Mandelbrot', 'download_url': 'https://github.com/Rain92/FPGA-Mandelbrot.git'}
# On No.42 repo: {'repo_id': 215869065, 'repo_name': 'bwitherspoon/wiphy', 'download_url': 'https://github.com/bwitherspoon/wiphy.git'}
# On No.43 repo: {'repo_id': 154533293, 'repo_name': 'taichi-ishitani/tbcm', 'download_url': 'https://github.com/taichi-ishitani/tbcm.git'}
# On No.44 repo: {'repo_id': 67240009, 'repo_name': 'go2uvm/sva_traces', 'download_url': 'https://github.com/go2uvm/sva_traces.git'}
# On No.45 repo: {'repo_id': 341675169, 'repo_name': 'semify-eda/go.debug', 'download_url': 'https://github.com/semify-eda/go.debug.git'}
# On No.46 repo: {'repo_id': 211245567, 'repo_name': 'AbhishekTaur/System-Verilog-Practice', 'download_url': 'https://github.com/AbhishekTaur/System-Verilog-Practice.git'}
# On No.47 repo: {'repo_id': 688517841, 'repo_name': 'MPSU/APS-reborn', 'download_url': 'https://github.com/MPSU/APS-reborn.git'}
# On No.48 repo: {'repo_id': 373854808, 'repo_name': 'avashist003/FIFO_SystemVerilog_Assertion', 'download_url': 'https://github.com/avashist003/FIFO_SystemVerilog_Assertion.git'}
# On No.49 repo: {'repo_id': 247762713, 'repo_name': 'chenyangbing/UVM-example', 'download_url': 'https://github.com/chenyangbing/UVM-example.git'}
# On No.50 repo: {'repo_id': 402685481, 'repo_name': 'ChrisShakkour/RV32I-MAF-project', 'download_url': 'https://github.com/ChrisShakkour/RV32I-MAF-project.git'}
# On No.51 repo: {'repo_id': 95138518, 'repo_name': 'kbbuch/LC3-Verification', 'download_url': 'https://github.com/kbbuch/LC3-Verification.git'}
# On No.52 repo: {'repo_id': 30703457, 'repo_name': 'amiq-consulting/amiq_dcr', 'download_url': 'https://github.com/amiq-consulting/amiq_dcr.git'}
# On No.53 repo: {'repo_id': 357352227, 'repo_name': 'msinger/dmg-sim', 'download_url': 'https://github.com/msinger/dmg-sim.git'}
# On No.54 repo: {'repo_id': 173373764, 'repo_name': 'atmughrabi/AccelGraph', 'download_url': 'https://github.com/atmughrabi/AccelGraph.git'}
# On No.55 repo: {'repo_id': 221727014, 'repo_name': 'PeterMonsson/lpcm-verilator', 'download_url': 'https://github.com/PeterMonsson/lpcm-verilator.git'}
# On No.56 repo: {'repo_id': 92110313, 'repo_name': 'cquickstad/uvm_unit', 'download_url': 'https://github.com/cquickstad/uvm_unit.git'}
# On No.57 repo: {'repo_id': 636531832, 'repo_name': 'AsFigo/pyslint', 'download_url': 'https://github.com/AsFigo/pyslint.git'}
# On No.58 repo: {'repo_id': 317413364, 'repo_name': 'seanpm2001/SNU_2D_ProgrammingTools_IDE_SystemVerilog', 'download_url': 'https://github.com/seanpm2001/SNU_2D_ProgrammingTools_IDE_SystemVerilog.git'}
# On No.59 repo: {'repo_id': 46694419, 'repo_name': 'dbretwolfe/UARTsv', 'download_url': 'https://github.com/dbretwolfe/UARTsv.git'}
# On No.60 repo: {'repo_id': 661703799, 'repo_name': 'taichi-ishitani/rice', 'download_url': 'https://github.com/taichi-ishitani/rice.git'}
# On No.61 repo: {'repo_id': 428956834, 'repo_name': 'jiru1997/design-and-verification-of-MCDF-phase3', 'download_url': 'https://github.com/jiru1997/design-and-verification-of-MCDF-phase3.git'}
# On No.62 repo: {'repo_id': 434686944, 'repo_name': 'GabbedT/Arithmetic-Circuits', 'download_url': 'https://github.com/GabbedT/Arithmetic-Circuits.git'}
# On No.63 repo: {'repo_id': 496668871, 'repo_name': 'dh73/uninterpreted_functions', 'download_url': 'https://github.com/dh73/uninterpreted_functions.git'}
# On No.64 repo: {'repo_id': 554060567, 'repo_name': 'Linger0/sv', 'download_url': 'https://github.com/Linger0/sv.git'}
# On No.65 repo: {'repo_id': 206828529, 'repo_name': 'CristianG89/Design_Digital_Systems_2', 'download_url': 'https://github.com/CristianG89/Design_Digital_Systems_2.git'}
# On No.66 repo: {'repo_id': 70977393, 'repo_name': 'atrifex/Contra-SV', 'download_url': 'https://github.com/atrifex/Contra-SV.git'}
# On No.67 repo: {'repo_id': 435489009, 'repo_name': 'daviddavo/tfg_poc_noc', 'download_url': 'https://github.com/daviddavo/tfg_poc_noc.git'}
# On No.68 repo: {'repo_id': 475424449, 'repo_name': 'MarleyLobao/UVM_calculator', 'download_url': 'https://github.com/MarleyLobao/UVM_calculator.git'}
# On No.69 repo: {'repo_id': 93367626, 'repo_name': 'jay16udani/ECE745_LC3_Verification', 'download_url': 'https://github.com/jay16udani/ECE745_LC3_Verification.git'}
# On No.70 repo: {'repo_id': 359465744, 'repo_name': 'Vivek-Dave/SystemVerilog', 'download_url': 'https://github.com/Vivek-Dave/SystemVerilog.git'}
# On No.71 repo: {'repo_id': 644086168, 'repo_name': 'AlPrime2k1/SystemVerilog', 'download_url': 'https://github.com/AlPrime2k1/SystemVerilog.git'}
# On No.72 repo: {'repo_id': 661945448, 'repo_name': 'asimkhan8107/SystemVerilog_30DAYS', 'download_url': 'https://github.com/asimkhan8107/SystemVerilog_30DAYS.git'}
